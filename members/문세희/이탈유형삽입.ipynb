# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 그래프 기본 테마 설정
# https://coldbrown.co.kr/2023/07/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EC%8B%A4%EC%A0%84%ED%8E%B8-08-seaborn-sns-set%EC%9D%84-%ED%86%B5%ED%95%B4-%EC%8A%A4%ED%83%80%EC%9D%BC-%EC%84%A4%EC%A0%95%ED%95%98%EA%B8%B0/
sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 14
plt.rcParams['axes.unicode_minus'] = False


# 복잡한 통계 처리를 위한 라이브러리
from scipy import stats

# %%
status = pd.read_csv('data/churn_status_preprocessing.csv')
status
# Out:
#             고객ID  분기  고객만족도점수   현재고객상태   이탈여부  이탈위험점수  고객생애가치  \
# 0     8779-QRDMV  Q3        3  Churned   True      91    5433
# 1     7495-OOKFY  Q3        3  Churned   True      69    5302
# 2     1658-BYGOY  Q3        2  Churned   True      81    3179
# 3     4598-XLKNJ  Q3        2  Churned   True      88    5337
# 4     4846-WHAFZ  Q3        2  Churned   True      67    2793
# ...          ...  ..      ...      ...    ...     ...     ...
# 7038  2569-WGERO  Q3        5   Stayed  False      45    5306
# 7039  6840-RESVB  Q3        3   Stayed  False      59    2140
# 7040  2234-XADUH  Q3        4   Stayed  False      71    5560
# 7041  4801-JZAZL  Q3        4   Stayed  False      59    2793
# 7042  3186-AJIEK  Q3        4   Stayed  False      38    5097
#
#                  이탈유형                          이탈사유
# 0          Competitor  Competitor offered more data
# 1          Competitor  Competitor made better offer
# 2          Competitor  Competitor made better offer
# 3     Dissatisfaction     Limited range of services
# 4               Price            Extra data charges
# ...               ...                           ...
# 7038              NaN                           NaN
# 7039              NaN                           NaN
# 7040              NaN                           NaN
# 7041              NaN                           NaN
# 7042              NaN                           NaN
#
# [7043 rows x 9 columns]

# %%
total = pd.read_csv('data/total_final.csv')
total
# Out:
#             고객ID         위도          경도     성별  고령자여부  배우자여부  부양가족여부  가입개월수  \
# 0     0002-ORFBO  34.827662 -118.999073  False  False   True   False      9
# 1     0003-MKNFE  34.162515 -118.203869   True  False  False   False      9
# 2     0004-TLHLJ  33.645672 -117.922613   True  False  False   False      4
# 3     0011-IGKFF  38.014457 -122.115432   True   True   True   False     13
# 4     0013-EXCHZ  34.227846 -119.079903  False   True   True   False      3
# ...          ...        ...         ...    ...    ...    ...     ...    ...
# 7038  9987-LUTYD  32.759327 -116.997260  False  False  False   False     13
# 7039  9992-RRAMN  37.734971 -120.954271   True  False   True   False     22
# 7040  9992-UJOEL  39.108252 -123.645121   True  False  False   False      2
# 7041  9993-LHIEB  33.001813 -117.263628   True  False   True   False     67
# 7042  9995-HOTOH  39.600599 -120.636358   True  False   True   False     63
#
#       전화서비스가입여부  복수회선여부  ...     가입혜택  장거리통화요금  월평균다운로드용량(GB)  프리미엄기술지원여부  \
# 0          True   False  ...       No    42.39             16        True
# 1          True    True  ...       No    10.69             10       False
# 2          True   False  ...  Offer E    33.65             30       False
# 3          True   False  ...  Offer D    27.82              4       False
# 4          True   False  ...       No     7.38             11        True
# ...         ...     ...  ...      ...      ...            ...         ...
# 7038       True   False  ...  Offer D    46.68             59        True
# 7039       True    True  ...  Offer D    16.20             17       False
# 7040       True   False  ...  Offer E    18.62             51       False
# 7041       True   False  ...  Offer A     2.12             58        True
# 7042      False   False  ...       No     0.00              5       False
#
#       음악스트리밍이용여부  무제한데이터이용여부   총환불액 총초과데이터요금  총장거리통화요금     총납부금
# 0          False        True   0.00        0    381.51   974.81
# 1           True       False  38.33       10     96.21   610.28
# 2          False        True   0.00        0    134.60   415.45
# 3          False        True   0.00        0    361.66  1599.51
# 4          False        True   0.00        0     22.14   289.54
# ...          ...         ...    ...      ...       ...      ...
# 7038        True        True   0.00        0    606.84  1349.74
# 7039        True        True   0.00        0    356.40  2230.10
# 7040       False        True   0.00        0     37.24   129.99
# 7041        True        True   0.00        0    142.04  4769.69
# 7042        True        True   0.00        0      0.00  3707.60
#
# [7043 rows x 43 columns]

# %%
## 데이터프레임을 넣고 column별 특성 및 결측값, 고유값들을 확인하는 함수를 작성해본다.
## 필수는 아니지만 전체적인 흐름을 파악하기 쉬워진다.

def resumetable(df):
  print(f'데이터셋 크기: {df.shape}')                                # 데이터프레임의 전체 크기(행, 열) 출력

  summary = pd.DataFrame(df.dtypes, columns=['데이터 타입'])         # 각 피처의 데이터 타입을 가져와 데이터프레임으로 생성
  summary = summary.reset_index()                                    # 인덱스를 초기화하여 컬럼으로 변환
  summary = summary.rename(columns={'index':'피처'})                 # 'index' 컬럼명을 '피처'로 변경

  summary['결측값 개수'] = df.isnull().sum().values                 # 각 피처의 결측값(null) 개수 계산
  summary['고유값 개수'] = df.nunique().values                      # 각 피처의 고유값 개수 계산

  summary['첫 번째 값'] = df.loc[0].values                          # 각 피처의 첫 번째 샘플 값
  summary['두 번째 값'] = df.loc[1].values                          # 각 피처의 두 번째 샘플 값
  summary['세 번째 값'] = df.loc[2].values                          # 각 피처의 세 번째 샘플 값

  return summary                                                     # 요약 테이블 반환

# %%
resumetable(total)
# Out:
# 데이터셋 크기: (7043, 43)
#                피처   데이터 타입  결측값 개수  고유값 개수        첫 번째 값          두 번째 값  \
# 0            고객ID   object       0    7043    0002-ORFBO      0003-MKNFE
# 1              위도  float64       0    1652     34.827662       34.162515
# 2              경도  float64       0    1651   -118.999073     -118.203869
# 3              성별     bool       0       2         False            True
# 4           고령자여부     bool       0       2         False           False
# 5           배우자여부     bool       0       2          True           False
# 6          부양가족여부     bool       0       2         False           False
# 7           가입개월수    int64       0      73             9               9
# 8       전화서비스가입여부     bool       0       2          True            True
# 9          복수회선여부     bool       0       2         False            True
# 10       인터넷서비스유형   object       0       3           DSL             DSL
# 11     온라인보안서비스여부     bool       0       2         False           False
# 12     온라인백업서비스여부     bool       0       2          True           False
# 13      기기보호서비스여부     bool       0       2         False           False
# 14      기술지원서비스여부     bool       0       2          True           False
# 15     TV스트리밍이용여부     bool       0       2          True           False
# 16     영화스트리밍이용여부     bool       0       2         False            True
# 17         계약기간유형   object       0       3      One year  Month-to-month
# 18      전자청구서이용여부     bool       0       2          True           False
# 19           결제방법   object       0       4  Mailed check    Mailed check
# 20            월요금  float64       0    1585          65.6            59.9
# 21            총요금  float64       0    6531         593.3           542.4
# 22           이탈여부     bool       0       2         False           False
# 23     이탈여부(bool)    int64       0       2             0               0
# 24         고객생애가치    int64       0    3438          2205            5414
# 25           이탈이유   object    5174      20           NaN             NaN
# 26             나이    int64       0      62            37              46
# 27        30세미만여부     bool       0       2         False           False
# 28          부양가족수    int64       0      10             0               0
# 29        고객만족도점수    int64       0       5             3               5
# 30         현재고객상태   object       0       3        Stayed          Stayed
# 31         친구추천여부     bool       0       2          True           False
# 32         친구추천횟수    int64       0      12             2               0
# 33           가입혜택   object       0       6            No              No
# 34        장거리통화요금  float64       0    3584         42.39           10.69
# 35  월평균다운로드용량(GB)    int64       0      50            16              10
# 36     프리미엄기술지원여부     bool       0       2          True           False
# 37     음악스트리밍이용여부     bool       0       2         False            True
# 38     무제한데이터이용여부     bool       0       2          True           False
# 39           총환불액  float64       0     500           0.0           38.33
# 40       총초과데이터요금    int64       0      16             0              10
# 41       총장거리통화요금  float64       0    6068        381.51           96.21
# 42           총납부금  float64       0    6975        974.81          610.28
#
#               세 번째 값
# 0         0004-TLHLJ
# 1          33.645672
# 2        -117.922613
# 3               True
# 4              False
# 5              False
# 6              False
# 7                  4
# 8               True
# 9              False
# 10       Fiber optic
# 11             False
# 12             False
# 13              True
# 14             False
# 15             False
# 16             False
# 17    Month-to-month
# 18              True
# 19  Electronic check
# 20              73.9
# 21            280.85
# 22              True
# 23                 1
# 24              4479
# 25    Price too high
# 26                50
# 27             False
# 28                 0
# 29                 1
# 30           Churned
# 31             False
# 32                 0
# 33           Offer E
# 34             33.65
# 35                30
# 36             False
# 37             False
# 38              True
# 39               0.0
# 40                 0
# 41             134.6
# 42            415.45

# %%
status_selected = status[['고객ID', '이탈유형']]
total_final = pd.merge(total, status_selected, on='고객ID', how = 'outer')
resumetable(total_final)
# Out:
# 데이터셋 크기: (7043, 44)
#                피처   데이터 타입  결측값 개수  고유값 개수        첫 번째 값          두 번째 값  \
# 0            고객ID   object       0    7043    0002-ORFBO      0003-MKNFE
# 1              위도  float64       0    1652     34.827662       34.162515
# 2              경도  float64       0    1651   -118.999073     -118.203869
# 3              성별     bool       0       2         False            True
# 4           고령자여부     bool       0       2         False           False
# 5           배우자여부     bool       0       2          True           False
# 6          부양가족여부     bool       0       2         False           False
# 7           가입개월수    int64       0      73             9               9
# 8       전화서비스가입여부     bool       0       2          True            True
# 9          복수회선여부     bool       0       2         False            True
# 10       인터넷서비스유형   object       0       3           DSL             DSL
# 11     온라인보안서비스여부     bool       0       2         False           False
# 12     온라인백업서비스여부     bool       0       2          True           False
# 13      기기보호서비스여부     bool       0       2         False           False
# 14      기술지원서비스여부     bool       0       2          True           False
# 15     TV스트리밍이용여부     bool       0       2          True           False
# 16     영화스트리밍이용여부     bool       0       2         False            True
# 17         계약기간유형   object       0       3      One year  Month-to-month
# 18      전자청구서이용여부     bool       0       2          True           False
# 19           결제방법   object       0       4  Mailed check    Mailed check
# 20            월요금  float64       0    1585          65.6            59.9
# 21            총요금  float64       0    6531         593.3           542.4
# 22           이탈여부     bool       0       2         False           False
# 23     이탈여부(bool)    int64       0       2             0               0
# 24         고객생애가치    int64       0    3438          2205            5414
# 25           이탈이유   object    5174      20           NaN             NaN
# 26             나이    int64       0      62            37              46
# 27        30세미만여부     bool       0       2         False           False
# 28          부양가족수    int64       0      10             0               0
# 29        고객만족도점수    int64       0       5             3               5
# 30         현재고객상태   object       0       3        Stayed          Stayed
# 31         친구추천여부     bool       0       2          True           False
# 32         친구추천횟수    int64       0      12             2               0
# 33           가입혜택   object       0       6            No              No
# 34        장거리통화요금  float64       0    3584         42.39           10.69
# 35  월평균다운로드용량(GB)    int64       0      50            16              10
# 36     프리미엄기술지원여부     bool       0       2          True           False
# 37     음악스트리밍이용여부     bool       0       2         False            True
# 38     무제한데이터이용여부     bool       0       2          True           False
# 39           총환불액  float64       0     500           0.0           38.33
# 40       총초과데이터요금    int64       0      16             0              10
# 41       총장거리통화요금  float64       0    6068        381.51           96.21
# 42           총납부금  float64       0    6975        974.81          610.28
# 43           이탈유형   object    5174       5           NaN             NaN
#
#               세 번째 값
# 0         0004-TLHLJ
# 1          33.645672
# 2        -117.922613
# 3               True
# 4              False
# 5              False
# 6              False
# 7                  4
# 8               True
# 9              False
# 10       Fiber optic
# 11             False
# 12             False
# 13              True
# 14             False
# 15             False
# 16             False
# 17    Month-to-month
# 18              True
# 19  Electronic check
# 20              73.9
# 21            280.85
# 22              True
# 23                 1
# 24              4479
# 25    Price too high
# 26                50
# 27             False
# 28                 0
# 29                 1
# 30           Churned
# 31             False
# 32                 0
# 33           Offer E
# 34             33.65
# 35                30
# 36             False
# 37             False
# 38              True
# 39               0.0
# 40                 0
# 41             134.6
# 42            415.45
# 43        Competitor

# %%
total_final['이탈유형'].value_counts()
# Out:
# 이탈유형
# Competitor         841
# Attitude           314
# Dissatisfaction    303
# Price              211
# Other              200
# Name: count, dtype: int64

# %%
churntype_translation = {
    'Competitor': '경쟁사로 이탈',
    'Attitude': '태도 문제',
    'Dissatisfaction': '불만족',
    'Price': '가격 문제',
    'Other': '기타'
}

# 매핑 적용
total_final['한글이탈유형'] = total_final['이탈유형'].map(churntype_translation)

# 결과 확인
print(total_final[['이탈유형', '한글이탈유형']].head())
# Out:
#               이탈유형   한글이탈유형
# 0              NaN      NaN
# 1              NaN      NaN
# 2       Competitor  경쟁사로 이탈
# 3  Dissatisfaction      불만족
# 4  Dissatisfaction      불만족

# %%
reason_mapping = {
    'Competitor made better offer': '경쟁사가 더 나은 제안을 했습니다',
    'Moved': '이동했습니다',
    'Competitor had better devices': '경쟁사가 더 나은 기기를 보유했습니다',
    'Competitor offered higher download speeds': '경쟁사가 더 빠른 다운로드 속도를 제공함',
    'Competitor offered more data': '경쟁사가 더 많은 데이터를 제공함',
    'Price too high': '가격이 너무 높음',
    'Product dissatisfaction': '제품 불만족',
    'Service dissatisfaction': '서비스 불만족',
    'Lack of self-service on Website': '웹사이트의 셀프 서비스 부족',
    'Network reliability': '네트워크 안정성',
    'Limited range of services': '제한된 서비스 범위',
    'Lack of affordable download/upload speed': '저렴한 다운로드/업로드 속도 부족',
    'Long distance charges': '장거리 요금',
    'Extra data charges': '추가 데이터 요금',
    "Don't know": '모르겠다',
    'Poor expertise of online support': '온라인 지원의 전문성 부족',
    'Poor expertise of phone support': '전화 지원의 전문성 부족',
    'Attitude of service provider': '서비스 제공업체의 태도',
    'Attitude of support person': '지원 담당자의 태도',
    'Deceased': '사망'
}

# %%
total_final['한글이탈이유'] = total_final['이탈이유'].map(reason_mapping)
total_final.head(20)
# Out:
#           고객ID         위도          경도     성별  고령자여부  배우자여부  부양가족여부  가입개월수  \
# 0   0002-ORFBO  34.827662 -118.999073  False  False   True   False      9
# 1   0003-MKNFE  34.162515 -118.203869   True  False  False   False      9
# 2   0004-TLHLJ  33.645672 -117.922613   True  False  False   False      4
# 3   0011-IGKFF  38.014457 -122.115432   True   True   True   False     13
# 4   0013-EXCHZ  34.227846 -119.079903  False   True   True   False      3
# 5   0013-MHZWF  37.581496 -119.972762  False  False  False    True      9
# 6   0013-SMEOE  34.757477 -120.550507  False   True   True   False     71
# 7   0014-BMAQU  38.489789 -122.270110   True  False   True   False     63
# 8   0015-UOCOJ  34.296813 -118.685703  False   True  False   False      7
# 9   0016-QLJIS  38.984756 -121.345074  False  False   True    True     65
# 10  0017-DINOC  32.993560 -117.207121   True  False  False   False     54
# 11  0017-IUDMW  37.378541 -122.020456  False  False   True    True     72
# 12  0018-NYROU  38.715498 -121.363411  False  False   True   False      5
# 13  0019-EFAEP  32.782501 -117.016110  False  False  False   False     72
# 14  0019-GFNTW  34.704340 -120.026090  False  False  False   False     56
# 15  0020-INWCK  36.464635 -119.094348  False  False   True    True     71
# 16  0020-JDNXP  38.060264 -122.830646  False  False   True    True     34
# 17  0021-IKXGC  33.119028 -117.166036  False   True  False   False      1
# 18  0022-TCJCI  37.680844 -122.481310   True   True  False   False     45
# 19  0023-HGHWL  37.161544 -121.649371   True   True  False   False      1
#
#     전화서비스가입여부  복수회선여부  ... 프리미엄기술지원여부  음악스트리밍이용여부  무제한데이터이용여부   총환불액  \
# 0        True   False  ...       True       False        True   0.00
# 1        True    True  ...      False        True       False  38.33
# 2        True   False  ...      False       False        True   0.00
# 3        True   False  ...      False       False        True   0.00
# 4        True   False  ...       True       False        True   0.00
# 5        True   False  ...       True        True        True   0.00
# 6        True   False  ...       True        True        True   0.00
# 7        True    True  ...       True       False       False   0.00
# 8        True   False  ...      False       False        True   0.00
# 9        True    True  ...       True        True        True   0.00
# 10      False   False  ...       True       False        True   0.00
# 11       True    True  ...       True        True        True   0.00
# 12       True   False  ...      False       False        True   0.00
# 13       True    True  ...      False       False        True   0.00
# 14      False   False  ...       True       False        True   0.00
# 15       True    True  ...      False        True        True   0.00
# 16      False   False  ...       True        True        True   0.00
# 17       True    True  ...      False       False        True   0.00
# 18       True   False  ...      False       False        True   0.00
# 19      False   False  ...      False       False        True   0.00
#
#     총초과데이터요금  총장거리통화요금     총납부금             이탈유형   한글이탈유형              한글이탈이유
# 0          0    381.51   974.81              NaN      NaN                 NaN
# 1         10     96.21   610.28              NaN      NaN                 NaN
# 2          0    134.60   415.45       Competitor  경쟁사로 이탈           가격이 너무 높음
# 3          0    361.66  1599.51  Dissatisfaction      불만족              제품 불만족
# 4          0     22.14   289.54  Dissatisfaction      불만족            네트워크 안정성
# 5          0    150.93   722.38              NaN      NaN                 NaN
# 6          0    707.16  8611.41              NaN      NaN                 NaN
# 7         20    816.48  6214.28              NaN      NaN                 NaN
# 8          0     73.71   414.06              NaN      NaN                 NaN
# 9          0   1849.90  7807.80              NaN      NaN                 NaN
# 10         0      0.00  2460.55              NaN      NaN                 NaN
# 11         0   1152.72  9609.47              NaN      NaN                 NaN
# 12         0     93.25   444.75              NaN      NaN                 NaN
# 13         0    162.00  7423.25              NaN      NaN                 NaN
# 14         0      0.00  2560.10              NaN      NaN                 NaN
# 15         0   1935.46  8784.86              NaN      NaN                 NaN
# 16         0      0.00  1993.20              NaN      NaN                 NaN
# 17         0      7.77    79.87              NaN      NaN                 NaN
# 18         0    480.15  3271.65  Dissatisfaction      불만족          제한된 서비스 범위
# 19         0      0.00    25.10       Competitor  경쟁사로 이탈  경쟁사가 더 나은 제안을 했습니다
#
# [20 rows x 46 columns]

# %%
# 이탈유형별 이탈이유별 개수
reason_counts_by_type = total_final.groupby('한글이탈유형')['한글이탈이유'].value_counts()

# 결과 확인
pd.DataFrame(reason_counts_by_type)
# Out:
#                                 count
# 한글이탈유형  한글이탈이유
# 가격 문제   가격이 너무 높음                  78
#         추가 데이터 요금                  40
#         장거리 요금                     35
#         저렴한 다운로드/업로드 속도 부족         31
#         모르겠다                        6
#         웹사이트의 셀프 서비스 부족             5
#         제품 불만족                      5
#         경쟁사가 더 나은 기기를 보유했습니다        4
#         서비스 제공업체의 태도                3
#         지원 담당자의 태도                  3
#         경쟁사가 더 빠른 다운로드 속도를 제공함      1
# 경쟁사로 이탈 경쟁사가 더 빠른 다운로드 속도를 제공함    158
#         경쟁사가 더 많은 데이터를 제공함        152
#         경쟁사가 더 나은 제안을 했습니다        136
#         경쟁사가 더 나은 기기를 보유했습니다      126
#         지원 담당자의 태도                 50
#         서비스 제공업체의 태도               40
#         네트워크 안정성                   26
#         서비스 불만족                    25
#         제품 불만족                     19
#         가격이 너무 높음                  18
#         웹사이트의 셀프 서비스 부족            16
#         추가 데이터 요금                  16
#         모르겠다                       15
#         장거리 요금                      9
#         저렴한 다운로드/업로드 속도 부족          8
#         전화 지원의 전문성 부족               8
#         이동했습니다                      7
#         온라인 지원의 전문성 부족              6
#         제한된 서비스 범위                  6
# 기타      모르겠다                      133
#         이동했습니다                     46
#         사망                          6
#         경쟁사가 더 나은 제안을 했습니다          4
#         가격이 너무 높음                   2
#         경쟁사가 더 빠른 다운로드 속도를 제공함      2
#         경쟁사가 더 많은 데이터를 제공함          1
#         네트워크 안정성                    1
#         서비스 불만족                     1
#         서비스 제공업체의 태도                1
#         제한된 서비스 범위                  1
#         지원 담당자의 태도                  1
#         추가 데이터 요금                   1
# 불만족     제품 불만족                     77
#         네트워크 안정성                   72
#         서비스 불만족                    63
#         제한된 서비스 범위                 37
#         웹사이트의 셀프 서비스 부족            29
#         온라인 지원의 전문성 부족             13
#         전화 지원의 전문성 부족              12
# 태도 문제   지원 담당자의 태도                138
#         서비스 제공업체의 태도               91
#         웹사이트의 셀프 서비스 부족            38
#         경쟁사가 더 빠른 다운로드 속도를 제공함     28
#         경쟁사가 더 많은 데이터를 제공함          9
#         저렴한 다운로드/업로드 속도 부족          5
#         네트워크 안정성                    4
#         제품 불만족                      1

# %%
total_final['한글이탈유형'].value_counts()
# Out:
# 한글이탈유형
# 경쟁사로 이탈    841
# 태도 문제      314
# 불만족        303
# 가격 문제      211
# 기타         200
# Name: count, dtype: int64

# %%
# total_final.to_csv('data/total_real_final.csv', index=False, encoding='utf-8-sig')

# %%
# 한글 컬럼 기준으로 필터링
filtered_df = total_final[
    (total_final['한글이탈유형'] == '가격') & 
    (total_final['한글이탈이유'] == '웹사이트의 셀프 서비스 부족')
]

# 결과 확인
print(filtered_df)
# Out:
# Empty DataFrame
# Columns: [고객ID, 위도, 경도, 성별, 고령자여부, 배우자여부, 부양가족여부, 가입개월수, 전화서비스가입여부, 복수회선여부, 인터넷서비스유형, 온라인보안서비스여부, 온라인백업서비스여부, 기기보호서비스여부, 기술지원서비스여부, TV스트리밍이용여부, 영화스트리밍이용여부, 계약기간유형, 전자청구서이용여부, 결제방법, 월요금, 총요금, 이탈여부, 이탈여부(bool), 고객생애가치, 이탈이유, 나이, 30세미만여부, 부양가족수, 고객만족도점수, 현재고객상태, 친구추천여부, 친구추천횟수, 가입혜택, 장거리통화요금, 월평균다운로드용량(GB), 프리미엄기술지원여부, 음악스트리밍이용여부, 무제한데이터이용여부, 총환불액, 총초과데이터요금, 총장거리통화요금, 총납부금, 이탈유형, 한글이탈유형, 한글이탈이유]
# Index: []
#
# [0 rows x 46 columns]
