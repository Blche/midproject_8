# %% [markdown]
# ## 초기 세팅

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 그래프 기본 테마 설정
# https://coldbrown.co.kr/2023/07/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EC%8B%A4%EC%A0%84%ED%8E%B8-08-seaborn-sns-set%EC%9D%84-%ED%86%B5%ED%95%B4-%EC%8A%A4%ED%83%80%EC%9D%BC-%EC%84%A4%EC%A0%95%ED%95%98%EA%B8%B0/
sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 14
plt.rcParams['axes.unicode_minus'] = False

# 복잡한 통계 처리를 위한 라이브러리
from scipy import stats

# %%
## 데이터프레임을 넣고 column별 특성 및 결측값, 고유값들을 확인하는 함수를 작성해본다.
## 필수는 아니지만 전체적인 흐름을 파악하기 쉬워진다.

def resumetable(df):
  print(f'데이터셋 크기: {df.shape}')                                # 데이터프레임의 전체 크기(행, 열) 출력

  summary = pd.DataFrame(df.dtypes, columns=['데이터 타입'])         # 각 피처의 데이터 타입을 가져와 데이터프레임으로 생성
  summary = summary.reset_index()                                    # 인덱스를 초기화하여 컬럼으로 변환
  summary = summary.rename(columns={'index':'피처'})                 # 'index' 컬럼명을 '피처'로 변경

  summary['결측값 개수'] = df.isnull().sum().values                 # 각 피처의 결측값(null) 개수 계산
  summary['고유값 개수'] = df.nunique().values                      # 각 피처의 고유값 개수 계산

  summary['첫 번째 값'] = df.loc[0].values                          # 각 피처의 첫 번째 샘플 값
  summary['두 번째 값'] = df.loc[1].values                          # 각 피처의 두 번째 샘플 값
  summary['세 번째 값'] = df.loc[2].values                          # 각 피처의 세 번째 샘플 값

  return summary                                                     # 요약 테이블 반환

# %%
tel = pd.read_csv('data/tel_data_onehotenco.csv')
new_churn = pd.read_excel('data/Telco_customer_churn.xlsx')
demographics = pd.read_excel('data/Telco_customer_churn_demographics.xlsx')
location = pd.read_excel('data/Telco_customer_churn_location.xlsx')
population = pd.read_excel('data/Telco_customer_churn_population.xlsx')
services = pd.read_excel('data/Telco_customer_churn_services.xlsx')
status = pd.read_excel('data/Telco_customer_churn_status.xlsx')

# %% [markdown]
# ---

# %% [markdown]
# # 데이터셋 확인

# %% [markdown]
# ### 원래 데이터셋

# %%
tel
# Out:
#       Unnamed: 0        고객ID     성별  고령자여부  배우자여부  부양가족여부  가입개월수  전화서비스가입여부  \
# 0              0  7590-VHVEG  False  False   True   False      1      False
# 1              1  5575-GNVDE   True  False  False   False     34       True
# 2              2  3668-QPYBK   True  False  False   False      2       True
# 3              3  7795-CFOCW   True  False  False   False     45      False
# 4              4  9237-HQITU  False  False  False   False      2       True
# ...          ...         ...    ...    ...    ...     ...    ...        ...
# 7038        7038  6840-RESVB   True  False   True    True     24       True
# 7039        7039  2234-XADUH  False  False   True    True     72       True
# 7040        7040  4801-JZAZL  False  False   True    True     11      False
# 7041        7041  8361-LTMKD   True   True   True   False      4       True
# 7042        7042  3186-AJIEK   True  False  False   False     66       True
#
#       복수회선여부     인터넷서비스유형  ...  TV스트리밍이용여부  영화스트리밍이용여부          계약기간유형  \
# 0      False          DSL  ...       False       False  Month-to-month
# 1      False          DSL  ...       False       False        One year
# 2      False          DSL  ...       False       False  Month-to-month
# 3      False          DSL  ...       False       False        One year
# 4      False  Fiber optic  ...       False       False  Month-to-month
# ...      ...          ...  ...         ...         ...             ...
# 7038    True          DSL  ...        True        True        One year
# 7039    True  Fiber optic  ...        True        True        One year
# 7040   False          DSL  ...       False       False  Month-to-month
# 7041    True  Fiber optic  ...       False       False  Month-to-month
# 7042   False  Fiber optic  ...        True        True        Two year
#
#       전자청구서이용여부                       결제방법     월요금      총요금   이탈여부 인터넷서비스가입여부  \
# 0          True           Electronic check   29.85    29.85  False       True
# 1         False               Mailed check   56.95  1889.50  False       True
# 2          True               Mailed check   53.85   108.15   True       True
# 3         False  Bank transfer (automatic)   42.30  1840.75  False       True
# 4          True           Electronic check   70.70   151.65   True       True
# ...         ...                        ...     ...      ...    ...        ...
# 7038       True               Mailed check   84.80  1990.50  False       True
# 7039       True    Credit card (automatic)  103.20  7362.90  False       True
# 7040       True           Electronic check   29.60   346.45  False       True
# 7041       True               Mailed check   74.40   306.60   True       True
# 7042       True  Bank transfer (automatic)  105.65  6844.50  False       True
#
#       개월수*월요금
# 0       29.85
# 1     1936.30
# 2      107.70
# 3     1903.50
# 4      141.40
# ...       ...
# 7038  2035.20
# 7039  7430.40
# 7040   325.60
# 7041   297.60
# 7042  6972.90
#
# [7043 rows x 24 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### 이탈률 있는 추가 데이터셋

# %%
new_churn
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# 0     33.964131, -118.272783  33.964131 -118.272783    Male  ...
# 1      34.059281, -118.30742  34.059281 -118.307420  Female  ...
# 2     34.048013, -118.293953  34.048013 -118.293953  Female  ...
# 3     34.062125, -118.315709  34.062125 -118.315709  Female  ...
# 4     34.039224, -118.266293  34.039224 -118.266293    Male  ...
# ...                      ...        ...         ...     ...  ...
# 7038  34.341737, -116.539416  34.341737 -116.539416  Female  ...
# 7039  34.667815, -117.536183  34.667815 -117.536183    Male  ...
# 7040  34.559882, -115.637164  34.559882 -115.637164  Female  ...
# 7041     34.1678, -116.86433  34.167800 -116.864330  Female  ...
# 7042  34.424926, -117.184503  34.424926 -117.184503    Male  ...
#
#             Contract Paperless Billing             Payment Method  \
# 0     Month-to-month               Yes               Mailed check
# 1     Month-to-month               Yes           Electronic check
# 2     Month-to-month               Yes           Electronic check
# 3     Month-to-month               Yes           Electronic check
# 4     Month-to-month               Yes  Bank transfer (automatic)
# ...              ...               ...                        ...
# 7038        Two year               Yes  Bank transfer (automatic)
# 7039        One year               Yes               Mailed check
# 7040        One year               Yes    Credit card (automatic)
# 7041  Month-to-month               Yes           Electronic check
# 7042        Two year               Yes  Bank transfer (automatic)
#
#       Monthly Charges Total Charges Churn Label Churn Value Churn Score  CLTV  \
# 0               53.85        108.15         Yes           1          86  3239
# 1               70.70        151.65         Yes           1          67  2701
# 2               99.65         820.5         Yes           1          86  5372
# 3              104.80       3046.05         Yes           1          84  5003
# 4              103.70        5036.3         Yes           1          89  5340
# ...               ...           ...         ...         ...         ...   ...
# 7038            21.15        1419.4          No           0          45  5306
# 7039            84.80        1990.5          No           0          59  2140
# 7040           103.20        7362.9          No           0          71  5560
# 7041            29.60        346.45          No           0          59  2793
# 7042           105.65        6844.5          No           0          38  5097
#
#                        Churn Reason
# 0      Competitor made better offer
# 1                             Moved
# 2                             Moved
# 3                             Moved
# 4     Competitor had better devices
# ...                             ...
# 7038                            NaN
# 7039                            NaN
# 7040                            NaN
# 7041                            NaN
# 7042                            NaN
#
# [7043 rows x 33 columns]

# %%
resumetable(new_churn)
# Out:
# 데이터셋 크기: (7043, 33)
#                    피처   데이터 타입  결측값 개수  고유값 개수                        첫 번째 값  \
# 0          CustomerID   object       0    7043                    3668-QPYBK
# 1               Count    int64       0       1                             1
# 2             Country   object       0       1                 United States
# 3               State   object       0       1                    California
# 4                City   object       0    1129                   Los Angeles
# 5            Zip Code    int64       0    1652                         90003
# 6            Lat Long   object       0    1652        33.964131, -118.272783
# 7            Latitude  float64       0    1652                     33.964131
# 8           Longitude  float64       0    1651                   -118.272783
# 9              Gender   object       0       2                          Male
# 10     Senior Citizen   object       0       2                            No
# 11            Partner   object       0       2                            No
# 12         Dependents   object       0       2                            No
# 13      Tenure Months    int64       0      73                             2
# 14      Phone Service   object       0       2                           Yes
# 15     Multiple Lines   object       0       3                            No
# 16   Internet Service   object       0       3                           DSL
# 17    Online Security   object       0       3                           Yes
# 18      Online Backup   object       0       3                           Yes
# 19  Device Protection   object       0       3                            No
# 20       Tech Support   object       0       3                            No
# 21       Streaming TV   object       0       3                            No
# 22   Streaming Movies   object       0       3                            No
# 23           Contract   object       0       3                Month-to-month
# 24  Paperless Billing   object       0       2                           Yes
# 25     Payment Method   object       0       4                  Mailed check
# 26    Monthly Charges  float64       0    1585                         53.85
# 27      Total Charges   object       0    6531                        108.15
# 28        Churn Label   object       0       2                           Yes
# 29        Churn Value    int64       0       2                             1
# 30        Churn Score    int64       0      85                            86
# 31               CLTV    int64       0    3438                          3239
# 32       Churn Reason   object    5174      20  Competitor made better offer
#
#                    두 번째 값                  세 번째 값
# 0              9237-HQITU              9305-CDSKC
# 1                       1                       1
# 2           United States           United States
# 3              California              California
# 4             Los Angeles             Los Angeles
# 5                   90005                   90006
# 6   34.059281, -118.30742  34.048013, -118.293953
# 7               34.059281               34.048013
# 8              -118.30742             -118.293953
# 9                  Female                  Female
# 10                     No                      No
# 11                     No                      No
# 12                    Yes                     Yes
# 13                      2                       8
# 14                    Yes                     Yes
# 15                     No                     Yes
# 16            Fiber optic             Fiber optic
# 17                     No                      No
# 18                     No                      No
# 19                     No                     Yes
# 20                     No                      No
# 21                     No                     Yes
# 22                     No                     Yes
# 23         Month-to-month          Month-to-month
# 24                    Yes                     Yes
# 25       Electronic check        Electronic check
# 26                   70.7                   99.65
# 27                 151.65                   820.5
# 28                    Yes                     Yes
# 29                      1                       1
# 30                     67                      86
# 31                   2701                    5372
# 32                  Moved                   Moved

# %% [markdown]
# ---

# %%
demographics
# Out:
#      Customer ID  Count  Gender  Age Under 30 Senior Citizen Married  \
# 0     8779-QRDMV      1    Male   78       No            Yes      No
# 1     7495-OOKFY      1  Female   74       No            Yes     Yes
# 2     1658-BYGOY      1    Male   71       No            Yes      No
# 3     4598-XLKNJ      1  Female   78       No            Yes     Yes
# 4     4846-WHAFZ      1  Female   80       No            Yes     Yes
# ...          ...    ...     ...  ...      ...            ...     ...
# 7038  2569-WGERO      1  Female   30       No             No      No
# 7039  6840-RESVB      1    Male   38       No             No     Yes
# 7040  2234-XADUH      1  Female   30       No             No     Yes
# 7041  4801-JZAZL      1  Female   32       No             No     Yes
# 7042  3186-AJIEK      1    Male   44       No             No      No
#
#      Dependents  Number of Dependents
# 0            No                     0
# 1           Yes                     1
# 2           Yes                     3
# 3           Yes                     1
# 4           Yes                     1
# ...         ...                   ...
# 7038         No                     0
# 7039        Yes                     2
# 7040        Yes                     2
# 7041        Yes                     2
# 7042         No                     0
#
# [7043 rows x 9 columns]

# %%
resumetable(demographics)
# Out:
# 데이터셋 크기: (7043, 9)
#                      피처  데이터 타입  결측값 개수  고유값 개수      첫 번째 값      두 번째 값  \
# 0           Customer ID  object       0    7043  8779-QRDMV  7495-OOKFY
# 1                 Count   int64       0       1           1           1
# 2                Gender  object       0       2        Male      Female
# 3                   Age   int64       0      62          78          74
# 4              Under 30  object       0       2          No          No
# 5        Senior Citizen  object       0       2         Yes         Yes
# 6               Married  object       0       2          No         Yes
# 7            Dependents  object       0       2          No         Yes
# 8  Number of Dependents   int64       0      10           0           1
#
#        세 번째 값
# 0  1658-BYGOY
# 1           1
# 2        Male
# 3          71
# 4          No
# 5         Yes
# 6          No
# 7         Yes
# 8           3

# %% [markdown]
# ---

# %%
location
# Out:
#      Customer ID  Count        Country       State          City  Zip Code  \
# 0     8779-QRDMV      1  United States  California   Los Angeles     90022
# 1     7495-OOKFY      1  United States  California   Los Angeles     90063
# 2     1658-BYGOY      1  United States  California   Los Angeles     90065
# 3     4598-XLKNJ      1  United States  California     Inglewood     90303
# 4     4846-WHAFZ      1  United States  California      Whittier     90602
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude
# 0      34.02381, -118.156582  34.023810 -118.156582
# 1     34.044271, -118.185237  34.044271 -118.185237
# 2     34.108833, -118.229715  34.108833 -118.229715
# 3     33.936291, -118.332639  33.936291 -118.332639
# 4     33.972119, -118.020188  33.972119 -118.020188
# ...                      ...        ...         ...
# 7038  34.341737, -116.539416  34.341737 -116.539416
# 7039  34.667815, -117.536183  34.667815 -117.536183
# 7040  34.559882, -115.637164  34.559882 -115.637164
# 7041     34.1678, -116.86433  34.167800 -116.864330
# 7042  34.424926, -117.184503  34.424926 -117.184503
#
# [7043 rows x 9 columns]

# %%
resumetable(location)
# Out:
# 데이터셋 크기: (7043, 9)
#             피처   데이터 타입  결측값 개수  고유값 개수                 첫 번째 값  \
# 0  Customer ID   object       0    7043             8779-QRDMV
# 1        Count    int64       0       1                      1
# 2      Country   object       0       1          United States
# 3        State   object       0       1             California
# 4         City   object       0    1106            Los Angeles
# 5     Zip Code    int64       0    1626                  90022
# 6     Lat Long   object       0    1679  34.02381, -118.156582
# 7     Latitude  float64       0    1626               34.02381
# 8    Longitude  float64       0    1625            -118.156582
#
#                    두 번째 값                  세 번째 값
# 0              7495-OOKFY              1658-BYGOY
# 1                       1                       1
# 2           United States           United States
# 3              California              California
# 4             Los Angeles             Los Angeles
# 5                   90063                   90065
# 6  34.044271, -118.185237  34.108833, -118.229715
# 7               34.044271               34.108833
# 8             -118.185237             -118.229715

# %% [markdown]
# ---

# %%
population
# Out:
#         ID  Zip Code  Population
# 0        1     90001       54492
# 1        2     90002       44586
# 2        3     90003       58198
# 3        4     90004       67852
# 4        5     90005       43019
# ...    ...       ...         ...
# 1666  1667     96145        4002
# 1667  1668     96146         942
# 1668  1669     96148         678
# 1669  1670     96150       33038
# 1670  1671     96161       15783
#
# [1671 rows x 3 columns]

# %%
resumetable(population)
# Out:
# 데이터셋 크기: (1671, 3)
#            피처 데이터 타입  결측값 개수  고유값 개수  첫 번째 값  두 번째 값  세 번째 값
# 0          ID  int64       0    1671       1       2       3
# 1    Zip Code  int64       0    1671   90001   90002   90003
# 2  Population  int64       0    1607   54492   44586   58198

# %% [markdown]
# ---

# %%
services
# Out:
#      Customer ID  Count Quarter Referred a Friend  Number of Referrals  \
# 0     8779-QRDMV      1      Q3                No                    0
# 1     7495-OOKFY      1      Q3               Yes                    1
# 2     1658-BYGOY      1      Q3                No                    0
# 3     4598-XLKNJ      1      Q3               Yes                    1
# 4     4846-WHAFZ      1      Q3               Yes                    1
# ...          ...    ...     ...               ...                  ...
# 7038  2569-WGERO      1      Q3                No                    0
# 7039  6840-RESVB      1      Q3               Yes                    1
# 7040  2234-XADUH      1      Q3               Yes                    4
# 7041  4801-JZAZL      1      Q3               Yes                    1
# 7042  3186-AJIEK      1      Q3                No                    0
#
#       Tenure in Months    Offer Phone Service  \
# 0                    1      NaN            No
# 1                    8  Offer E           Yes
# 2                   18  Offer D           Yes
# 3                   25  Offer C           Yes
# 4                   37  Offer C           Yes
# ...                ...      ...           ...
# 7038                72      NaN           Yes
# 7039                24  Offer C           Yes
# 7040                72      NaN           Yes
# 7041                11      NaN            No
# 7042                66      NaN           Yes
#
#       Avg Monthly Long Distance Charges Multiple Lines  ... Unlimited Data  \
# 0                                  0.00             No  ...             No
# 1                                 48.85            Yes  ...            Yes
# 2                                 11.33            Yes  ...            Yes
# 3                                 19.76             No  ...            Yes
# 4                                  6.33            Yes  ...            Yes
# ...                                 ...            ...  ...            ...
# 7038                              22.77             No  ...             No
# 7039                              36.05            Yes  ...            Yes
# 7040                              29.66            Yes  ...            Yes
# 7041                               0.00             No  ...            Yes
# 7042                              30.96             No  ...            Yes
#
#             Contract  Paperless Billing   Payment Method Monthly Charge  \
# 0     Month-to-Month                Yes  Bank Withdrawal          39.65
# 1     Month-to-Month                Yes      Credit Card          80.65
# 2     Month-to-Month                Yes  Bank Withdrawal          95.45
# 3     Month-to-Month                Yes  Bank Withdrawal          98.50
# 4     Month-to-Month                Yes  Bank Withdrawal          76.50
# ...              ...                ...              ...            ...
# 7038        Two Year                Yes  Bank Withdrawal          21.15
# 7039        One Year                Yes     Mailed Check          84.80
# 7040        One Year                Yes      Credit Card         103.20
# 7041  Month-to-Month                Yes  Bank Withdrawal          29.60
# 7042        Two Year                Yes  Bank Withdrawal         105.65
#
#      Total Charges Total Refunds Total Extra Data Charges  \
# 0            39.65          0.00                       20
# 1           633.30          0.00                        0
# 2          1752.55         45.61                        0
# 3          2514.50         13.43                        0
# 4          2868.15          0.00                        0
# ...            ...           ...                      ...
# 7038       1419.40         19.31                        0
# 7039       1990.50         48.23                        0
# 7040       7362.90         45.38                        0
# 7041        346.45         27.24                        0
# 7042       6844.50          0.00                        0
#
#      Total Long Distance Charges Total Revenue
# 0                           0.00         59.65
# 1                         390.80       1024.10
# 2                         203.94       1910.88
# 3                         494.00       2995.07
# 4                         234.21       3102.36
# ...                          ...           ...
# 7038                     1639.44       3039.53
# 7039                      865.20       2807.47
# 7040                     2135.52       9453.04
# 7041                        0.00        319.21
# 7042                     2043.36       8887.86
#
# [7043 rows x 30 columns]

# %%
resumetable(services)
# Out:
# 데이터셋 크기: (7043, 30)
#                                    피처   데이터 타입  결측값 개수  고유값 개수  \
# 0                         Customer ID   object       0    7043
# 1                               Count    int64       0       1
# 2                             Quarter   object       0       1
# 3                   Referred a Friend   object       0       2
# 4                 Number of Referrals    int64       0      12
# 5                    Tenure in Months    int64       0      72
# 6                               Offer   object    3877       5
# 7                       Phone Service   object       0       2
# 8   Avg Monthly Long Distance Charges  float64       0    3584
# 9                      Multiple Lines   object       0       2
# 10                   Internet Service   object       0       2
# 11                      Internet Type   object    1526       3
# 12            Avg Monthly GB Download    int64       0      50
# 13                    Online Security   object       0       2
# 14                      Online Backup   object       0       2
# 15             Device Protection Plan   object       0       2
# 16               Premium Tech Support   object       0       2
# 17                       Streaming TV   object       0       2
# 18                   Streaming Movies   object       0       2
# 19                    Streaming Music   object       0       2
# 20                     Unlimited Data   object       0       2
# 21                           Contract   object       0       3
# 22                  Paperless Billing   object       0       2
# 23                     Payment Method   object       0       3
# 24                     Monthly Charge  float64       0    1585
# 25                      Total Charges  float64       0    6540
# 26                      Total Refunds  float64       0     500
# 27           Total Extra Data Charges    int64       0      16
# 28        Total Long Distance Charges  float64       0    6110
# 29                      Total Revenue  float64       0    6996
#
#              첫 번째 값          두 번째 값           세 번째 값
# 0        8779-QRDMV      7495-OOKFY       1658-BYGOY
# 1                 1               1                1
# 2                Q3              Q3               Q3
# 3                No             Yes               No
# 4                 0               1                0
# 5                 1               8               18
# 6               NaN         Offer E          Offer D
# 7                No             Yes              Yes
# 8               0.0           48.85            11.33
# 9                No             Yes              Yes
# 10              Yes             Yes              Yes
# 11              DSL     Fiber Optic      Fiber Optic
# 12                8              17               52
# 13               No              No               No
# 14               No             Yes               No
# 15              Yes              No               No
# 16               No              No               No
# 17               No              No              Yes
# 18              Yes              No              Yes
# 19               No              No              Yes
# 20               No             Yes              Yes
# 21   Month-to-Month  Month-to-Month   Month-to-Month
# 22              Yes             Yes              Yes
# 23  Bank Withdrawal     Credit Card  Bank Withdrawal
# 24            39.65           80.65            95.45
# 25            39.65           633.3          1752.55
# 26              0.0             0.0            45.61
# 27               20               0                0
# 28              0.0           390.8           203.94
# 29            59.65          1024.1          1910.88

# %% [markdown]
# ---

# %%
status
# Out:
#      Customer ID  Count Quarter  Satisfaction Score Customer Status  \
# 0     8779-QRDMV      1      Q3                   3         Churned
# 1     7495-OOKFY      1      Q3                   3         Churned
# 2     1658-BYGOY      1      Q3                   2         Churned
# 3     4598-XLKNJ      1      Q3                   2         Churned
# 4     4846-WHAFZ      1      Q3                   2         Churned
# ...          ...    ...     ...                 ...             ...
# 7038  2569-WGERO      1      Q3                   5          Stayed
# 7039  6840-RESVB      1      Q3                   3          Stayed
# 7040  2234-XADUH      1      Q3                   4          Stayed
# 7041  4801-JZAZL      1      Q3                   4          Stayed
# 7042  3186-AJIEK      1      Q3                   4          Stayed
#
#      Churn Label  Churn Value  Churn Score  CLTV   Churn Category  \
# 0            Yes            1           91  5433       Competitor
# 1            Yes            1           69  5302       Competitor
# 2            Yes            1           81  3179       Competitor
# 3            Yes            1           88  5337  Dissatisfaction
# 4            Yes            1           67  2793            Price
# ...          ...          ...          ...   ...              ...
# 7038          No            0           45  5306              NaN
# 7039          No            0           59  2140              NaN
# 7040          No            0           71  5560              NaN
# 7041          No            0           59  2793              NaN
# 7042          No            0           38  5097              NaN
#
#                       Churn Reason
# 0     Competitor offered more data
# 1     Competitor made better offer
# 2     Competitor made better offer
# 3        Limited range of services
# 4               Extra data charges
# ...                            ...
# 7038                           NaN
# 7039                           NaN
# 7040                           NaN
# 7041                           NaN
# 7042                           NaN
#
# [7043 rows x 11 columns]

# %%
resumetable(status)
# Out:
# 데이터셋 크기: (7043, 11)
#                     피처  데이터 타입  결측값 개수  고유값 개수                        첫 번째 값  \
# 0          Customer ID  object       0    7043                    8779-QRDMV
# 1                Count   int64       0       1                             1
# 2              Quarter  object       0       1                            Q3
# 3   Satisfaction Score   int64       0       5                             3
# 4      Customer Status  object       0       3                       Churned
# 5          Churn Label  object       0       2                           Yes
# 6          Churn Value   int64       0       2                             1
# 7          Churn Score   int64       0      81                            91
# 8                 CLTV   int64       0    3438                          5433
# 9       Churn Category  object    5174       5                    Competitor
# 10        Churn Reason  object    5174      20  Competitor offered more data
#
#                           두 번째 값                        세 번째 값
# 0                     7495-OOKFY                    1658-BYGOY
# 1                              1                             1
# 2                             Q3                            Q3
# 3                              3                             2
# 4                        Churned                       Churned
# 5                            Yes                           Yes
# 6                              1                             1
# 7                             69                            81
# 8                           5302                          3179
# 9                     Competitor                    Competitor
# 10  Competitor made better offer  Competitor made better offer

# %%
resumetable(new_churn)
# Out:
# 데이터셋 크기: (7043, 33)
#                    피처   데이터 타입  결측값 개수  고유값 개수                        첫 번째 값  \
# 0          CustomerID   object       0    7043                    3668-QPYBK
# 1               Count    int64       0       1                             1
# 2             Country   object       0       1                 United States
# 3               State   object       0       1                    California
# 4                City   object       0    1129                   Los Angeles
# 5            Zip Code    int64       0    1652                         90003
# 6            Lat Long   object       0    1652        33.964131, -118.272783
# 7            Latitude  float64       0    1652                     33.964131
# 8           Longitude  float64       0    1651                   -118.272783
# 9              Gender   object       0       2                          Male
# 10     Senior Citizen   object       0       2                            No
# 11            Partner   object       0       2                            No
# 12         Dependents   object       0       2                            No
# 13      Tenure Months    int64       0      73                             2
# 14      Phone Service   object       0       2                           Yes
# 15     Multiple Lines   object       0       3                            No
# 16   Internet Service   object       0       3                           DSL
# 17    Online Security   object       0       3                           Yes
# 18      Online Backup   object       0       3                           Yes
# 19  Device Protection   object       0       3                            No
# 20       Tech Support   object       0       3                            No
# 21       Streaming TV   object       0       3                            No
# 22   Streaming Movies   object       0       3                            No
# 23           Contract   object       0       3                Month-to-month
# 24  Paperless Billing   object       0       2                           Yes
# 25     Payment Method   object       0       4                  Mailed check
# 26    Monthly Charges  float64       0    1585                         53.85
# 27      Total Charges   object       0    6531                        108.15
# 28        Churn Label   object       0       2                           Yes
# 29        Churn Value    int64       0       2                             1
# 30        Churn Score    int64       0      85                            86
# 31               CLTV    int64       0    3438                          3239
# 32       Churn Reason   object    5174      20  Competitor made better offer
#
#                    두 번째 값                  세 번째 값
# 0              9237-HQITU              9305-CDSKC
# 1                       1                       1
# 2           United States           United States
# 3              California              California
# 4             Los Angeles             Los Angeles
# 5                   90005                   90006
# 6   34.059281, -118.30742  34.048013, -118.293953
# 7               34.059281               34.048013
# 8              -118.30742             -118.293953
# 9                  Female                  Female
# 10                     No                      No
# 11                     No                      No
# 12                    Yes                     Yes
# 13                      2                       8
# 14                    Yes                     Yes
# 15                     No                     Yes
# 16            Fiber optic             Fiber optic
# 17                     No                      No
# 18                     No                      No
# 19                     No                     Yes
# 20                     No                      No
# 21                     No                     Yes
# 22                     No                     Yes
# 23         Month-to-month          Month-to-month
# 24                    Yes                     Yes
# 25       Electronic check        Electronic check
# 26                   70.7                   99.65
# 27                 151.65                   820.5
# 28                    Yes                     Yes
# 29                      1                       1
# 30                     67                      86
# 31                   2701                    5372
# 32                  Moved                   Moved
