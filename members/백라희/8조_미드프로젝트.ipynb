# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 그래프 기본 테마 설정
# https://coldbrown.co.kr/2023/07/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EC%8B%A4%EC%A0%84%ED%8E%B8-08-seaborn-sns-set%EC%9D%84-%ED%86%B5%ED%95%B4-%EC%8A%A4%ED%83%80%EC%9D%BC-%EC%84%A4%EC%A0%95%ED%95%98%EA%B8%B0/
sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 14
plt.rcParams['axes.unicode_minus'] = False


# 복잡한 통계 처리를 위한 라이브러리
from scipy import stats

# %%
tel = pd.read_csv('data/tel.csv')
tel
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95        1889.5
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 21 columns]

# %%
## 데이터프레임을 넣고 column별 특성 및 결측값, 고유값들을 확인하는 함수를 작성해본다.
## 필수는 아니지만 전체적인 흐름을 파악하기 쉬워진다.

def resumetable(df):
  print(f'데이터셋 크기: {df.shape}')                                # 데이터프레임의 전체 크기(행, 열) 출력

  summary = pd.DataFrame(df.dtypes, columns=['데이터 타입'])         # 각 피처의 데이터 타입을 가져와 데이터프레임으로 생성
  summary = summary.reset_index()                                    # 인덱스를 초기화하여 컬럼으로 변환
  summary = summary.rename(columns={'index':'피처'})                 # 'index' 컬럼명을 '피처'로 변경

  summary['결측값 개수'] = df.isnull().sum().values                 # 각 피처의 결측값(null) 개수 계산
  summary['고유값 개수'] = df.nunique().values                      # 각 피처의 고유값 개수 계산

  summary['첫 번째 값'] = df.loc[0].values                          # 각 피처의 첫 번째 샘플 값
  summary['두 번째 값'] = df.loc[1].values                          # 각 피처의 두 번째 샘플 값
  summary['세 번째 값'] = df.loc[2].values                          # 각 피처의 세 번째 샘플 값

  return summary                                                     # 요약 테이블 반환

# %%
resumetable(tel)
# Out:
# 데이터셋 크기: (7043, 21)
#                   피처   데이터 타입  결측값 개수  고유값 개수            첫 번째 값        두 번째 값  \
# 0         customerID   object       0    7043        7590-VHVEG    5575-GNVDE
# 1             gender   object       0       2            Female          Male
# 2      SeniorCitizen    int64       0       2                 0             0
# 3            Partner   object       0       2               Yes            No
# 4         Dependents   object       0       2                No            No
# 5             tenure    int64       0      73                 1            34
# 6       PhoneService   object       0       2                No           Yes
# 7      MultipleLines   object       0       3  No phone service            No
# 8    InternetService   object       0       3               DSL           DSL
# 9     OnlineSecurity   object       0       3                No           Yes
# 10      OnlineBackup   object       0       3               Yes            No
# 11  DeviceProtection   object       0       3                No           Yes
# 12       TechSupport   object       0       3                No            No
# 13       StreamingTV   object       0       3                No            No
# 14   StreamingMovies   object       0       3                No            No
# 15          Contract   object       0       3    Month-to-month      One year
# 16  PaperlessBilling   object       0       2               Yes            No
# 17     PaymentMethod   object       0       4  Electronic check  Mailed check
# 18    MonthlyCharges  float64       0    1585             29.85         56.95
# 19      TotalCharges   object       0    6531             29.85        1889.5
# 20             Churn   object       0       2                No            No
#
#             세 번째 값
# 0       3668-QPYBK
# 1             Male
# 2                0
# 3               No
# 4               No
# 5                2
# 6              Yes
# 7               No
# 8              DSL
# 9              Yes
# 10             Yes
# 11              No
# 12              No
# 13              No
# 14              No
# 15  Month-to-month
# 16             Yes
# 17    Mailed check
# 18           53.85
# 19          108.15
# 20             Yes

# %%
tel = tel.rename(columns={
    'customerID': '고객ID',
    'gender': '성별',
    'SeniorCitizen': '고령자여부',
    'Partner': '배우자여부',
    'Dependents': '부양가족여부',
    'tenure': '가입개월수',
    'PhoneService': '전화서비스가입여부',
    'MultipleLines': '복수회선여부',
    'InternetService': '인터넷서비스유형',
    'OnlineSecurity': '온라인보안서비스여부',
    'OnlineBackup': '온라인백업서비스여부',
    'DeviceProtection': '기기보호서비스여부',
    'TechSupport': '기술지원서비스여부',
    'StreamingTV': 'TV스트리밍이용여부',
    'StreamingMovies': '영화스트리밍이용여부',
    'Contract': '계약기간유형',
    'PaperlessBilling': '전자청구서이용여부',
    'PaymentMethod': '결제방법',
    'MonthlyCharges': '월요금',
    'TotalCharges': '총요금',
    'Churn': '이탈여부'
})

# %%
tel['고령자여부'] = tel['고령자여부'].replace({1: 'Yes', 0: 'No'})

# %%
tel['인터넷서비스가입여부'] = tel['온라인보안서비스여부'] == 'No internet service'

# %%
tel['인터넷서비스가입여부'] = ~tel['인터넷서비스가입여부']

# %%
tel.head(20)
# Out:
#           고객ID      성별 고령자여부 배우자여부 부양가족여부  가입개월수 전화서비스가입여부            복수회선여부  \
# 0   7590-VHVEG  Female    No   Yes     No      1        No  No phone service
# 1   5575-GNVDE    Male    No    No     No     34       Yes                No
# 2   3668-QPYBK    Male    No    No     No      2       Yes                No
# 3   7795-CFOCW    Male    No    No     No     45        No  No phone service
# 4   9237-HQITU  Female    No    No     No      2       Yes                No
# 5   9305-CDSKC  Female    No    No     No      8       Yes               Yes
# 6   1452-KIOVK    Male    No    No    Yes     22       Yes               Yes
# 7   6713-OKOMC  Female    No    No     No     10        No  No phone service
# 8   7892-POOKP  Female    No   Yes     No     28       Yes               Yes
# 9   6388-TABGU    Male    No    No    Yes     62       Yes                No
# 10  9763-GRSKD    Male    No   Yes    Yes     13       Yes                No
# 11  7469-LKBCI    Male    No    No     No     16       Yes                No
# 12  8091-TTVAX    Male    No   Yes     No     58       Yes               Yes
# 13  0280-XJGEX    Male    No    No     No     49       Yes               Yes
# 14  5129-JLPIS    Male    No    No     No     25       Yes                No
# 15  3655-SNQYZ  Female    No   Yes    Yes     69       Yes               Yes
# 16  8191-XWSZG  Female    No    No     No     52       Yes                No
# 17  9959-WOFKT    Male    No    No    Yes     71       Yes               Yes
# 18  4190-MFLUW  Female    No   Yes    Yes     10       Yes                No
# 19  4183-MYFRB  Female    No    No     No     21       Yes                No
#
#        인터넷서비스유형           온라인보안서비스여부  ...            기술지원서비스여부  \
# 0           DSL                   No  ...                   No
# 1           DSL                  Yes  ...                   No
# 2           DSL                  Yes  ...                   No
# 3           DSL                  Yes  ...                  Yes
# 4   Fiber optic                   No  ...                   No
# 5   Fiber optic                   No  ...                   No
# 6   Fiber optic                   No  ...                   No
# 7           DSL                  Yes  ...                   No
# 8   Fiber optic                   No  ...                  Yes
# 9           DSL                  Yes  ...                   No
# 10          DSL                  Yes  ...                   No
# 11           No  No internet service  ...  No internet service
# 12  Fiber optic                   No  ...                   No
# 13  Fiber optic                   No  ...                   No
# 14  Fiber optic                  Yes  ...                  Yes
# 15  Fiber optic                  Yes  ...                  Yes
# 16           No  No internet service  ...  No internet service
# 17  Fiber optic                  Yes  ...                   No
# 18          DSL                   No  ...                  Yes
# 19  Fiber optic                   No  ...                   No
#
#              TV스트리밍이용여부           영화스트리밍이용여부          계약기간유형 전자청구서이용여부  \
# 0                    No                   No  Month-to-month       Yes
# 1                    No                   No        One year        No
# 2                    No                   No  Month-to-month       Yes
# 3                    No                   No        One year        No
# 4                    No                   No  Month-to-month       Yes
# 5                   Yes                  Yes  Month-to-month       Yes
# 6                   Yes                   No  Month-to-month       Yes
# 7                    No                   No  Month-to-month        No
# 8                   Yes                  Yes  Month-to-month       Yes
# 9                    No                   No        One year        No
# 10                   No                   No  Month-to-month       Yes
# 11  No internet service  No internet service        Two year        No
# 12                  Yes                  Yes        One year        No
# 13                  Yes                  Yes  Month-to-month       Yes
# 14                  Yes                  Yes  Month-to-month       Yes
# 15                  Yes                  Yes        Two year        No
# 16  No internet service  No internet service        One year        No
# 17                  Yes                  Yes        Two year        No
# 18                   No                   No  Month-to-month        No
# 19                   No                  Yes  Month-to-month       Yes
#
#                          결제방법     월요금      총요금  이탈여부 인터넷서비스가입여부
# 0            Electronic check   29.85    29.85    No       True
# 1                Mailed check   56.95   1889.5    No       True
# 2                Mailed check   53.85   108.15   Yes       True
# 3   Bank transfer (automatic)   42.30  1840.75    No       True
# 4            Electronic check   70.70   151.65   Yes       True
# 5            Electronic check   99.65    820.5   Yes       True
# 6     Credit card (automatic)   89.10   1949.4    No       True
# 7                Mailed check   29.75    301.9    No       True
# 8            Electronic check  104.80  3046.05   Yes       True
# 9   Bank transfer (automatic)   56.15  3487.95    No       True
# 10               Mailed check   49.95   587.45    No       True
# 11    Credit card (automatic)   18.95    326.8    No      False
# 12    Credit card (automatic)  100.35   5681.1    No       True
# 13  Bank transfer (automatic)  103.70   5036.3   Yes       True
# 14           Electronic check  105.50  2686.05    No       True
# 15    Credit card (automatic)  113.25  7895.15    No       True
# 16               Mailed check   20.65  1022.95    No      False
# 17  Bank transfer (automatic)  106.70  7382.25    No       True
# 18    Credit card (automatic)   55.20   528.35   Yes       True
# 19           Electronic check   90.05   1862.9    No       True
#
# [20 rows x 22 columns]

# %%
tel['복수회선여부'] = tel['복수회선여부'].replace({'No phone service': 'No'})

# %%
cols = ['온라인보안서비스여부', '온라인백업서비스여부', '기기보호서비스여부', '기술지원서비스여부',
        'TV스트리밍이용여부', '영화스트리밍이용여부']

tel[cols] = tel[cols].replace('No internet service', 'No')

# %%
tel.head(20)
# Out:
#           고객ID      성별 고령자여부 배우자여부 부양가족여부  가입개월수 전화서비스가입여부 복수회선여부  \
# 0   7590-VHVEG  Female    No   Yes     No      1        No     No
# 1   5575-GNVDE    Male    No    No     No     34       Yes     No
# 2   3668-QPYBK    Male    No    No     No      2       Yes     No
# 3   7795-CFOCW    Male    No    No     No     45        No     No
# 4   9237-HQITU  Female    No    No     No      2       Yes     No
# 5   9305-CDSKC  Female    No    No     No      8       Yes    Yes
# 6   1452-KIOVK    Male    No    No    Yes     22       Yes    Yes
# 7   6713-OKOMC  Female    No    No     No     10        No     No
# 8   7892-POOKP  Female    No   Yes     No     28       Yes    Yes
# 9   6388-TABGU    Male    No    No    Yes     62       Yes     No
# 10  9763-GRSKD    Male    No   Yes    Yes     13       Yes     No
# 11  7469-LKBCI    Male    No    No     No     16       Yes     No
# 12  8091-TTVAX    Male    No   Yes     No     58       Yes    Yes
# 13  0280-XJGEX    Male    No    No     No     49       Yes    Yes
# 14  5129-JLPIS    Male    No    No     No     25       Yes     No
# 15  3655-SNQYZ  Female    No   Yes    Yes     69       Yes    Yes
# 16  8191-XWSZG  Female    No    No     No     52       Yes     No
# 17  9959-WOFKT    Male    No    No    Yes     71       Yes    Yes
# 18  4190-MFLUW  Female    No   Yes    Yes     10       Yes     No
# 19  4183-MYFRB  Female    No    No     No     21       Yes     No
#
#        인터넷서비스유형 온라인보안서비스여부  ... 기술지원서비스여부 TV스트리밍이용여부 영화스트리밍이용여부  \
# 0           DSL         No  ...        No         No         No
# 1           DSL        Yes  ...        No         No         No
# 2           DSL        Yes  ...        No         No         No
# 3           DSL        Yes  ...       Yes         No         No
# 4   Fiber optic         No  ...        No         No         No
# 5   Fiber optic         No  ...        No        Yes        Yes
# 6   Fiber optic         No  ...        No        Yes         No
# 7           DSL        Yes  ...        No         No         No
# 8   Fiber optic         No  ...       Yes        Yes        Yes
# 9           DSL        Yes  ...        No         No         No
# 10          DSL        Yes  ...        No         No         No
# 11           No         No  ...        No         No         No
# 12  Fiber optic         No  ...        No        Yes        Yes
# 13  Fiber optic         No  ...        No        Yes        Yes
# 14  Fiber optic        Yes  ...       Yes        Yes        Yes
# 15  Fiber optic        Yes  ...       Yes        Yes        Yes
# 16           No         No  ...        No         No         No
# 17  Fiber optic        Yes  ...        No        Yes        Yes
# 18          DSL         No  ...       Yes         No         No
# 19  Fiber optic         No  ...        No         No        Yes
#
#             계약기간유형 전자청구서이용여부                       결제방법     월요금      총요금  \
# 0   Month-to-month       Yes           Electronic check   29.85    29.85
# 1         One year        No               Mailed check   56.95   1889.5
# 2   Month-to-month       Yes               Mailed check   53.85   108.15
# 3         One year        No  Bank transfer (automatic)   42.30  1840.75
# 4   Month-to-month       Yes           Electronic check   70.70   151.65
# 5   Month-to-month       Yes           Electronic check   99.65    820.5
# 6   Month-to-month       Yes    Credit card (automatic)   89.10   1949.4
# 7   Month-to-month        No               Mailed check   29.75    301.9
# 8   Month-to-month       Yes           Electronic check  104.80  3046.05
# 9         One year        No  Bank transfer (automatic)   56.15  3487.95
# 10  Month-to-month       Yes               Mailed check   49.95   587.45
# 11        Two year        No    Credit card (automatic)   18.95    326.8
# 12        One year        No    Credit card (automatic)  100.35   5681.1
# 13  Month-to-month       Yes  Bank transfer (automatic)  103.70   5036.3
# 14  Month-to-month       Yes           Electronic check  105.50  2686.05
# 15        Two year        No    Credit card (automatic)  113.25  7895.15
# 16        One year        No               Mailed check   20.65  1022.95
# 17        Two year        No  Bank transfer (automatic)  106.70  7382.25
# 18  Month-to-month        No    Credit card (automatic)   55.20   528.35
# 19  Month-to-month       Yes           Electronic check   90.05   1862.9
#
#     이탈여부 인터넷서비스가입여부
# 0     No       True
# 1     No       True
# 2    Yes       True
# 3     No       True
# 4    Yes       True
# 5    Yes       True
# 6     No       True
# 7     No       True
# 8    Yes       True
# 9     No       True
# 10    No       True
# 11    No      False
# 12    No       True
# 13   Yes       True
# 14    No       True
# 15    No       True
# 16    No      False
# 17    No       True
# 18   Yes       True
# 19    No       True
#
# [20 rows x 22 columns]

# %%
resumetable(tel)
# Out:
# 데이터셋 크기: (7043, 22)
#             피처   데이터 타입  결측값 개수  고유값 개수            첫 번째 값        두 번째 값  \
# 0         고객ID   object       0    7043        7590-VHVEG    5575-GNVDE
# 1           성별   object       0       2            Female          Male
# 2        고령자여부   object       0       2                No            No
# 3        배우자여부   object       0       2               Yes            No
# 4       부양가족여부   object       0       2                No            No
# 5        가입개월수    int64       0      73                 1            34
# 6    전화서비스가입여부   object       0       2                No           Yes
# 7       복수회선여부   object       0       2                No            No
# 8     인터넷서비스유형   object       0       3               DSL           DSL
# 9   온라인보안서비스여부   object       0       2                No           Yes
# 10  온라인백업서비스여부   object       0       2               Yes            No
# 11   기기보호서비스여부   object       0       2                No           Yes
# 12   기술지원서비스여부   object       0       2                No            No
# 13  TV스트리밍이용여부   object       0       2                No            No
# 14  영화스트리밍이용여부   object       0       2                No            No
# 15      계약기간유형   object       0       3    Month-to-month      One year
# 16   전자청구서이용여부   object       0       2               Yes            No
# 17        결제방법   object       0       4  Electronic check  Mailed check
# 18         월요금  float64       0    1585             29.85         56.95
# 19         총요금   object       0    6531             29.85        1889.5
# 20        이탈여부   object       0       2                No            No
# 21  인터넷서비스가입여부     bool       0       2              True          True
#
#             세 번째 값
# 0       3668-QPYBK
# 1             Male
# 2               No
# 3               No
# 4               No
# 5                2
# 6              Yes
# 7               No
# 8              DSL
# 9              Yes
# 10             Yes
# 11              No
# 12              No
# 13              No
# 14              No
# 15  Month-to-month
# 16             Yes
# 17    Mailed check
# 18           53.85
# 19          108.15
# 20             Yes
# 21            True

# %%
tel.replace({'Yes': True, 'No': False},inplace = True)
# Out:
# C:\Users\win11\AppData\Local\Temp\ipykernel_19164\67169591.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tel.replace({'Yes': True, 'No': False},inplace = True)

# %%
tel['성별'] = tel['성별'].replace({'Male': True, 'Female': False})
# Out:
# C:\Users\win11\AppData\Local\Temp\ipykernel_19164\1917428603.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tel['성별'] = tel['성별'].replace({'Male': True, 'Female': False})

# %%
tel.head(20)
# Out:
#           고객ID     성별  고령자여부  배우자여부  부양가족여부  가입개월수  전화서비스가입여부  복수회선여부  \
# 0   7590-VHVEG  False  False   True   False      1      False   False
# 1   5575-GNVDE   True  False  False   False     34       True   False
# 2   3668-QPYBK   True  False  False   False      2       True   False
# 3   7795-CFOCW   True  False  False   False     45      False   False
# 4   9237-HQITU  False  False  False   False      2       True   False
# 5   9305-CDSKC  False  False  False   False      8       True    True
# 6   1452-KIOVK   True  False  False    True     22       True    True
# 7   6713-OKOMC  False  False  False   False     10      False   False
# 8   7892-POOKP  False  False   True   False     28       True    True
# 9   6388-TABGU   True  False  False    True     62       True   False
# 10  9763-GRSKD   True  False   True    True     13       True   False
# 11  7469-LKBCI   True  False  False   False     16       True   False
# 12  8091-TTVAX   True  False   True   False     58       True    True
# 13  0280-XJGEX   True  False  False   False     49       True    True
# 14  5129-JLPIS   True  False  False   False     25       True   False
# 15  3655-SNQYZ  False  False   True    True     69       True    True
# 16  8191-XWSZG  False  False  False   False     52       True   False
# 17  9959-WOFKT   True  False  False    True     71       True    True
# 18  4190-MFLUW  False  False   True    True     10       True   False
# 19  4183-MYFRB  False  False  False   False     21       True   False
#
#        인터넷서비스유형  온라인보안서비스여부  ...  기술지원서비스여부  TV스트리밍이용여부  영화스트리밍이용여부  \
# 0           DSL       False  ...      False       False       False
# 1           DSL        True  ...      False       False       False
# 2           DSL        True  ...      False       False       False
# 3           DSL        True  ...       True       False       False
# 4   Fiber optic       False  ...      False       False       False
# 5   Fiber optic       False  ...      False        True        True
# 6   Fiber optic       False  ...      False        True       False
# 7           DSL        True  ...      False       False       False
# 8   Fiber optic       False  ...       True        True        True
# 9           DSL        True  ...      False       False       False
# 10          DSL        True  ...      False       False       False
# 11        False       False  ...      False       False       False
# 12  Fiber optic       False  ...      False        True        True
# 13  Fiber optic       False  ...      False        True        True
# 14  Fiber optic        True  ...       True        True        True
# 15  Fiber optic        True  ...       True        True        True
# 16        False       False  ...      False       False       False
# 17  Fiber optic        True  ...      False        True        True
# 18          DSL       False  ...       True       False       False
# 19  Fiber optic       False  ...      False       False        True
#
#             계약기간유형  전자청구서이용여부                       결제방법     월요금      총요금  \
# 0   Month-to-month       True           Electronic check   29.85    29.85
# 1         One year      False               Mailed check   56.95   1889.5
# 2   Month-to-month       True               Mailed check   53.85   108.15
# 3         One year      False  Bank transfer (automatic)   42.30  1840.75
# 4   Month-to-month       True           Electronic check   70.70   151.65
# 5   Month-to-month       True           Electronic check   99.65    820.5
# 6   Month-to-month       True    Credit card (automatic)   89.10   1949.4
# 7   Month-to-month      False               Mailed check   29.75    301.9
# 8   Month-to-month       True           Electronic check  104.80  3046.05
# 9         One year      False  Bank transfer (automatic)   56.15  3487.95
# 10  Month-to-month       True               Mailed check   49.95   587.45
# 11        Two year      False    Credit card (automatic)   18.95    326.8
# 12        One year      False    Credit card (automatic)  100.35   5681.1
# 13  Month-to-month       True  Bank transfer (automatic)  103.70   5036.3
# 14  Month-to-month       True           Electronic check  105.50  2686.05
# 15        Two year      False    Credit card (automatic)  113.25  7895.15
# 16        One year      False               Mailed check   20.65  1022.95
# 17        Two year      False  Bank transfer (automatic)  106.70  7382.25
# 18  Month-to-month      False    Credit card (automatic)   55.20   528.35
# 19  Month-to-month       True           Electronic check   90.05   1862.9
#
#      이탈여부 인터넷서비스가입여부
# 0   False       True
# 1   False       True
# 2    True       True
# 3   False       True
# 4    True       True
# 5    True       True
# 6   False       True
# 7   False       True
# 8    True       True
# 9   False       True
# 10  False       True
# 11  False      False
# 12  False       True
# 13   True       True
# 14  False       True
# 15  False       True
# 16  False      False
# 17  False       True
# 18   True       True
# 19  False       True
#
# [20 rows x 22 columns]

# %%
tel.dtypes
# Out:
# 고객ID           object
# 성별               bool
# 고령자여부            bool
# 배우자여부            bool
# 부양가족여부           bool
# 가입개월수           int64
# 전화서비스가입여부        bool
# 복수회선여부           bool
# 인터넷서비스유형       object
# 온라인보안서비스여부       bool
# 온라인백업서비스여부       bool
# 기기보호서비스여부        bool
# 기술지원서비스여부        bool
# TV스트리밍이용여부       bool
# 영화스트리밍이용여부       bool
# 계약기간유형         object
# 전자청구서이용여부        bool
# 결제방법           object
# 월요금           float64
# 총요금            object
# 이탈여부             bool
# 인터넷서비스가입여부       bool
# dtype: object

# %%
tel['결제방법'].value_counts()
# Out:
# 결제방법
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
a1 = tel[['배우자여부', '이탈여부']]
a1
# Out:
#       배우자여부   이탈여부
# 0      True  False
# 1     False  False
# 2     False   True
# 3     False  False
# 4     False   True
# ...     ...    ...
# 7038   True  False
# 7039   True  False
# 7040   True  False
# 7041   True   True
# 7042  False  False
#
# [7043 rows x 2 columns]

# %%
partner = tel['배우자여부'].value_counts()
partner.index = ['배우자 없음', '배우자 있음']
color1 = ['#70d6ff', '#ff70a6']

churn = tel['이탈여부'].value_counts()
churn.index = ['잔류', '이탈']
color2 = ['#ff70a6', '#70d6ff']

# 배우자가 있다, 없다 비율
plt.subplot(1, 2, 1)
plt.pie(
    partner,
    labels=partner.index,
    autopct='%.1f%%',
    startangle=90,
    colors=color1
)
plt.title('배우자 여부 비율')
plt.ylabel('')

# 이탈을 했다, 안했다 비율
plt.subplot(1, 2, 2)
plt.pie(
    churn,
    labels=churn.index,
    autopct='%.1f%%',
    startangle=90,
    colors=color2
)
plt.title('이탈 여부 비율')
plt.ylabel('')

plt.show()

# %%
# 교차표 생성
grouped = tel.groupby(['배우자여부', '이탈여부']).size().unstack()

# 색상 지정
colors = ['#ffd6e0', '#90e0ef']  # 잔류, 이탈

# subplot으로 파이차트 2개 그리기
plt.figure(figsize=(12, 5))

# 배우자 없음 (False)
plt.subplot(1, 2, 1)
plt.pie(
    grouped.loc[False],
    labels=['잔류', '이탈'],
    autopct='%.1f%%',
    startangle=90,
    colors=colors
)
plt.title('배우자 없음')
plt.ylabel('')

# 배우자 있음 (True)
plt.subplot(1, 2, 2)
plt.pie(
    grouped.loc[True],
    labels=['잔류', '이탈'],
    autopct='%.1f%%',
    startangle=90,
    colors=colors
)
plt.title('배우자 있음')
plt.ylabel('')

plt.suptitle('배우자 여부에 따른 이탈 여부 비율', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# 배우자 유무에 따른 이탈 여부 (countplot)

plt.figure(figsize=(7,5))

sns.countplot(
    data=tel, 
    x='배우자여부', 
    hue='이탈여부',
    palette='pastel'
)

plt.title('배우자 유무에 따른 이탈 여부')
plt.xticks([0,1], ['배우자 없음', '배우자 있음'])
plt.xlabel('배우자 여부')
plt.ylabel('고객 수')
plt.legend(title='이탈 여부', labels=['잔류','이탈'])
plt.show()

# %%
# 이탈 여부에 따른 배우자 유무 (countplot)

plt.figure(figsize=(7,5))

sns.countplot(
    data=tel, 
    x='이탈여부', 
    hue='배우자여부',
    palette='summer',
)

plt.title('이탈 여부에 따른 배우자 유무')
plt.xticks([0,1], ['잔류', '이탈'])
plt.xlabel('이탈 여부')
plt.ylabel('고객 수')
plt.legend(title='배우자 여부', labels=['없음','있음'])
plt.show()

# %%
# 인터넷서비스유형에 따른 이탈 비율 (파이차트)

# 원본 데이터 프레임 copy
tel_copy = tel.copy()
tel_copy['인터넷서비스유형'] = tel_copy['인터넷서비스유형'].replace({False: 'No Internet Service'})

# %%
# 교차표 생성
grouped = tel_copy.groupby(['인터넷서비스유형', '이탈여부']).size().unstack()

# 색상
colors = ['#43aa8b', '#f3722c']  # 잔류, 이탈

# subplot으로 파이차트 3개 그리기
plt.figure(figsize=(18, 5))

services = ['Fiber optic', 'DSL', 'No Internet Service']

for i, service in enumerate(services):
    plt.subplot(1, 3, i + 1)
    plt.pie(
        grouped.loc[service],
        labels=['잔류', '이탈'],
        autopct='%.1f%%',
        startangle=90,
        colors=colors
    )
    plt.title(service)
    plt.ylabel('')

plt.suptitle('인터넷 서비스 유형에 따른 이탈 여부 비율', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# 인터넷서비스유형에 따른 이탈 비율 (countplot)

plt.figure(figsize=(7,5))

sns.countplot(
    data=tel, 
    x='인터넷서비스유형', 
    hue='이탈여부',
    palette='Set2'
)

plt.title('인터넷 서비스 유형에 따른 이탈 여부')
plt.xticks([0,1,2], ['Fiber optic', 'DSL', 'No Internet Service'])
plt.xlabel('')
plt.ylabel('고객 수')
plt.legend(title='이탈 여부', labels=['잔류','이탈'])
plt.show()

# %%
tel_copy['인터넷서비스유형'].value_counts()
# Out:
# 인터넷서비스유형
# Fiber optic            3096
# DSL                    2421
# No Internet Service    1526
# Name: count, dtype: int64

# %%
tel['인터넷서비스유형'].value_counts()
# Out:
# 인터넷서비스유형
# Fiber optic    3096
# DSL            2421
# False          1526
# Name: count, dtype: int64

# %%
print(grouped.index)
# Out:
# Index(['DSL', 'Fiber optic', 'No Internet Service'], dtype='object', name='인터넷서비스유형')

# %%
tel['총요금'].value_counts()
# Out:
# 총요금
#           11
# 20.2      11
# 19.75      9
# 20.05      8
# 19.9       8
#           ..
# 6849.4     1
# 692.35     1
# 130.15     1
# 3211.9     1
# 6844.5     1
# Name: count, Length: 6531, dtype: int64

# %%
tel.head(10)
# Out:
#          고객ID     성별  고령자여부  배우자여부  부양가족여부  가입개월수  전화서비스가입여부  복수회선여부  \
# 0  7590-VHVEG  False  False   True   False      1      False   False
# 1  5575-GNVDE   True  False  False   False     34       True   False
# 2  3668-QPYBK   True  False  False   False      2       True   False
# 3  7795-CFOCW   True  False  False   False     45      False   False
# 4  9237-HQITU  False  False  False   False      2       True   False
# 5  9305-CDSKC  False  False  False   False      8       True    True
# 6  1452-KIOVK   True  False  False    True     22       True    True
# 7  6713-OKOMC  False  False  False   False     10      False   False
# 8  7892-POOKP  False  False   True   False     28       True    True
# 9  6388-TABGU   True  False  False    True     62       True   False
#
#       인터넷서비스유형  온라인보안서비스여부  ...  기술지원서비스여부  TV스트리밍이용여부  영화스트리밍이용여부  \
# 0          DSL       False  ...      False       False       False
# 1          DSL        True  ...      False       False       False
# 2          DSL        True  ...      False       False       False
# 3          DSL        True  ...       True       False       False
# 4  Fiber optic       False  ...      False       False       False
# 5  Fiber optic       False  ...      False        True        True
# 6  Fiber optic       False  ...      False        True       False
# 7          DSL        True  ...      False       False       False
# 8  Fiber optic       False  ...       True        True        True
# 9          DSL        True  ...      False       False       False
#
#            계약기간유형  전자청구서이용여부                       결제방법     월요금      총요금  \
# 0  Month-to-month       True           Electronic check   29.85    29.85
# 1        One year      False               Mailed check   56.95   1889.5
# 2  Month-to-month       True               Mailed check   53.85   108.15
# 3        One year      False  Bank transfer (automatic)   42.30  1840.75
# 4  Month-to-month       True           Electronic check   70.70   151.65
# 5  Month-to-month       True           Electronic check   99.65    820.5
# 6  Month-to-month       True    Credit card (automatic)   89.10   1949.4
# 7  Month-to-month      False               Mailed check   29.75    301.9
# 8  Month-to-month       True           Electronic check  104.80  3046.05
# 9        One year      False  Bank transfer (automatic)   56.15  3487.95
#
#     이탈여부 인터넷서비스가입여부
# 0  False       True
# 1  False       True
# 2   True       True
# 3  False       True
# 4   True       True
# 5   True       True
# 6  False       True
# 7  False       True
# 8   True       True
# 9  False       True
#
# [10 rows x 22 columns]

# %%
tel['총요금'] = tel['총요금'].replace(' ', 0)
tel['총요금'] = tel['총요금'].astype(float)

# %%
tel[tel['총요금']== 0]
# Out:
#             고객ID     성별  고령자여부  배우자여부  부양가족여부  가입개월수  전화서비스가입여부  복수회선여부  \
# 488   4472-LVYGI  False  False   True    True      0      False   False
# 753   3115-CZMZD   True  False  False    True      0       True   False
# 936   5709-LVOEQ  False  False   True    True      0       True   False
# 1082  4367-NUYAO   True  False   True    True      0       True    True
# 1340  1371-DWPAZ  False  False   True    True      0      False   False
# 3331  7644-OMVMY   True  False   True    True      0       True   False
# 3826  3213-VVOLG   True  False   True    True      0       True    True
# 4380  2520-SGTTA  False  False   True    True      0       True   False
# 5218  2923-ARZLG   True  False   True    True      0       True   False
# 6670  4075-WKNIU  False  False   True    True      0       True    True
# 6754  2775-SEFEE   True  False  False    True      0       True    True
#
#      인터넷서비스유형  온라인보안서비스여부  ...  기술지원서비스여부  TV스트리밍이용여부  영화스트리밍이용여부    계약기간유형  \
# 488       DSL        True  ...       True        True       False  Two year
# 753     False       False  ...      False       False       False  Two year
# 936       DSL        True  ...      False        True        True  Two year
# 1082    False       False  ...      False       False       False  Two year
# 1340      DSL        True  ...       True        True       False  Two year
# 3331    False       False  ...      False       False       False  Two year
# 3826    False       False  ...      False       False       False  Two year
# 4380    False       False  ...      False       False       False  Two year
# 5218    False       False  ...      False       False       False  One year
# 6670      DSL       False  ...       True        True       False  Two year
# 6754      DSL        True  ...       True       False       False  Two year
#
#       전자청구서이용여부                       결제방법    월요금  총요금   이탈여부  인터넷서비스가입여부
# 488        True  Bank transfer (automatic)  52.55  0.0  False        True
# 753       False               Mailed check  20.25  0.0  False       False
# 936       False               Mailed check  80.85  0.0  False        True
# 1082      False               Mailed check  25.75  0.0  False       False
# 1340      False    Credit card (automatic)  56.05  0.0  False        True
# 3331      False               Mailed check  19.85  0.0  False       False
# 3826      False               Mailed check  25.35  0.0  False       False
# 4380      False               Mailed check  20.00  0.0  False       False
# 5218       True               Mailed check  19.70  0.0  False       False
# 6670      False               Mailed check  73.35  0.0  False        True
# 6754       True  Bank transfer (automatic)  61.90  0.0  False        True
#
# [11 rows x 22 columns]

# %%
tel['개월수*월요금'] = tel['가입개월수'] * tel['월요금']

# %%
tel
# Out:
#             고객ID     성별  고령자여부  배우자여부  부양가족여부  가입개월수  전화서비스가입여부  복수회선여부  \
# 0     7590-VHVEG  False  False   True   False      1      False   False
# 1     5575-GNVDE   True  False  False   False     34       True   False
# 2     3668-QPYBK   True  False  False   False      2       True   False
# 3     7795-CFOCW   True  False  False   False     45      False   False
# 4     9237-HQITU  False  False  False   False      2       True   False
# ...          ...    ...    ...    ...     ...    ...        ...     ...
# 7038  6840-RESVB   True  False   True    True     24       True    True
# 7039  2234-XADUH  False  False   True    True     72       True    True
# 7040  4801-JZAZL  False  False   True    True     11      False   False
# 7041  8361-LTMKD   True   True   True   False      4       True    True
# 7042  3186-AJIEK   True  False  False   False     66       True   False
#
#          인터넷서비스유형  온라인보안서비스여부  ...  TV스트리밍이용여부  영화스트리밍이용여부          계약기간유형  \
# 0             DSL       False  ...       False       False  Month-to-month
# 1             DSL        True  ...       False       False        One year
# 2             DSL        True  ...       False       False  Month-to-month
# 3             DSL        True  ...       False       False        One year
# 4     Fiber optic       False  ...       False       False  Month-to-month
# ...           ...         ...  ...         ...         ...             ...
# 7038          DSL        True  ...        True        True        One year
# 7039  Fiber optic       False  ...        True        True        One year
# 7040          DSL        True  ...       False       False  Month-to-month
# 7041  Fiber optic       False  ...       False       False  Month-to-month
# 7042  Fiber optic        True  ...        True        True        Two year
#
#       전자청구서이용여부                       결제방법     월요금      총요금   이탈여부  \
# 0          True           Electronic check   29.85    29.85  False
# 1         False               Mailed check   56.95  1889.50  False
# 2          True               Mailed check   53.85   108.15   True
# 3         False  Bank transfer (automatic)   42.30  1840.75  False
# 4          True           Electronic check   70.70   151.65   True
# ...         ...                        ...     ...      ...    ...
# 7038       True               Mailed check   84.80  1990.50  False
# 7039       True    Credit card (automatic)  103.20  7362.90  False
# 7040       True           Electronic check   29.60   346.45  False
# 7041       True               Mailed check   74.40   306.60   True
# 7042       True  Bank transfer (automatic)  105.65  6844.50  False
#
#       인터넷서비스가입여부  개월수*월요금
# 0           True    29.85
# 1           True  1936.30
# 2           True   107.70
# 3           True  1903.50
# 4           True   141.40
# ...          ...      ...
# 7038        True  2035.20
# 7039        True  7430.40
# 7040        True   325.60
# 7041        True   297.60
# 7042        True  6972.90
#
# [7043 rows x 23 columns]

# %%
numeric_df = tel.select_dtypes(include=['number', 'bool'])
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#                   성별     고령자여부     배우자여부    부양가족여부     가입개월수  전화서비스가입여부  \
# 성별          1.000000 -0.001874 -0.001808  0.010517  0.005106  -0.006488
# 고령자여부      -0.001874  1.000000  0.016479 -0.211185  0.016567   0.008576
# 배우자여부      -0.001808  0.016479  1.000000  0.452676  0.379697   0.017706
# 부양가족여부      0.010517 -0.211185  0.452676  1.000000  0.159712  -0.001762
# 가입개월수       0.005106  0.016567  0.379697  0.159712  1.000000   0.008448
# 전화서비스가입여부  -0.006488  0.008576  0.017706 -0.001762  0.008448   1.000000
# 복수회선여부     -0.008414  0.142948  0.142057 -0.024526  0.331941   0.279690
# 온라인보안서비스여부 -0.017021 -0.038653  0.143106  0.080972  0.327203  -0.092893
# 온라인백업서비스여부 -0.013773  0.066572  0.141498  0.023671  0.360277  -0.052312
# 기기보호서비스여부  -0.002105  0.059428  0.153786  0.013963  0.360653  -0.071227
# 기술지원서비스여부  -0.009212 -0.060625  0.119999  0.063268  0.324221  -0.096340
# TV스트리밍이용여부 -0.008393  0.105378  0.124666 -0.016558  0.279756  -0.022574
# 영화스트리밍이용여부 -0.010487  0.120176  0.117412 -0.039741  0.286111  -0.032959
# 전자청구서이용여부  -0.011754  0.156530 -0.014877 -0.111377  0.006152   0.016505
# 월요금        -0.014569  0.220173  0.096848 -0.113890  0.247900   0.247398
# 총요금        -0.000080  0.103006  0.317504  0.062078  0.826178   0.113214
# 이탈여부       -0.008612  0.150889 -0.150448 -0.164221 -0.352229   0.011942
# 인터넷서비스가입여부 -0.006026  0.182742 -0.000615 -0.139812  0.039062  -0.172209
# 개월수*월요금    -0.000029  0.103261  0.317462  0.062290  0.826568   0.113336
#
#               복수회선여부  온라인보안서비스여부  온라인백업서비스여부  기기보호서비스여부  기술지원서비스여부  \
# 성별         -0.008414   -0.017021   -0.013773  -0.002105  -0.009212
# 고령자여부       0.142948   -0.038653    0.066572   0.059428  -0.060625
# 배우자여부       0.142057    0.143106    0.141498   0.153786   0.119999
# 부양가족여부     -0.024526    0.080972    0.023671   0.013963   0.063268
# 가입개월수       0.331941    0.327203    0.360277   0.360653   0.324221
# 전화서비스가입여부   0.279690   -0.092893   -0.052312  -0.071227  -0.096340
# 복수회선여부      1.000000    0.098108    0.202237   0.201137   0.100571
# 온라인보안서비스여부  0.098108    1.000000    0.283832   0.275438   0.354931
# 온라인백업서비스여부  0.202237    0.283832    1.000000   0.303546   0.294233
# 기기보호서비스여부   0.201137    0.275438    0.303546   1.000000   0.333313
# 기술지원서비스여부   0.100571    0.354931    0.294233   0.333313   1.000000
# TV스트리밍이용여부  0.257152    0.176207    0.282106   0.390874   0.278070
# 영화스트리밍이용여부  0.258751    0.187398    0.274501   0.402111   0.279358
# 전자청구서이용여부   0.163530   -0.003636    0.126735   0.103797   0.037880
# 월요금         0.490434    0.296594    0.441780   0.482692   0.338304
# 총요금         0.468504    0.411651    0.509226   0.521983   0.431883
# 이탈여부        0.040102   -0.171226   -0.082255  -0.066160  -0.164674
# 인터넷서비스가입여부  0.210564    0.333403    0.381593   0.380754   0.336298
# 개월수*월요금     0.468748    0.411816    0.509754   0.521748   0.431817
#
#             TV스트리밍이용여부  영화스트리밍이용여부  전자청구서이용여부       월요금       총요금      이탈여부  \
# 성별           -0.008393   -0.010487  -0.011754 -0.014569 -0.000080 -0.008612
# 고령자여부         0.105378    0.120176   0.156530  0.220173  0.103006  0.150889
# 배우자여부         0.124666    0.117412  -0.014877  0.096848  0.317504 -0.150448
# 부양가족여부       -0.016558   -0.039741  -0.111377 -0.113890  0.062078 -0.164221
# 가입개월수         0.279756    0.286111   0.006152  0.247900  0.826178 -0.352229
# 전화서비스가입여부    -0.022574   -0.032959   0.016505  0.247398  0.113214  0.011942
# 복수회선여부        0.257152    0.258751   0.163530  0.490434  0.468504  0.040102
# 온라인보안서비스여부    0.176207    0.187398  -0.003636  0.296594  0.411651 -0.171226
# 온라인백업서비스여부    0.282106    0.274501   0.126735  0.441780  0.509226 -0.082255
# 기기보호서비스여부     0.390874    0.402111   0.103797  0.482692  0.521983 -0.066160
# 기술지원서비스여부     0.278070    0.279358   0.037880  0.338304  0.431883 -0.164674
# TV스트리밍이용여부    1.000000    0.533094   0.223841  0.629603  0.514973  0.063228
# 영화스트리밍이용여부    0.533094    1.000000   0.211716  0.627429  0.520122  0.061382
# 전자청구서이용여부     0.223841    0.211716   1.000000  0.352150  0.158574  0.191825
# 월요금           0.629603    0.627429   0.352150  1.000000  0.651174  0.193356
# 총요금           0.514973    0.520122   0.158574  0.651174  1.000000 -0.198324
# 이탈여부          0.063228    0.061382   0.191825  0.193356 -0.198324  1.000000
# 인터넷서비스가입여부    0.415552    0.418675   0.321013  0.763557  0.375223  0.227890
# 개월수*월요금       0.515267    0.520005   0.158843  0.651566  0.999561 -0.198514
#
#             인터넷서비스가입여부   개월수*월요금
# 성별           -0.006026 -0.000029
# 고령자여부         0.182742  0.103261
# 배우자여부        -0.000615  0.317462
# 부양가족여부       -0.139812  0.062290
# 가입개월수         0.039062  0.826568
# 전화서비스가입여부    -0.172209  0.113336
# 복수회선여부        0.210564  0.468748
# 온라인보안서비스여부    0.333403  0.411816
# 온라인백업서비스여부    0.381593  0.509754
# 기기보호서비스여부     0.380754  0.521748
# 기술지원서비스여부     0.336298  0.431817
# TV스트리밍이용여부    0.415552  0.515267
# 영화스트리밍이용여부    0.418675  0.520005
# 전자청구서이용여부     0.321013  0.158843
# 월요금           0.763557  0.651566
# 총요금           0.375223  0.999561
# 이탈여부          0.227890 -0.198514
# 인터넷서비스가입여부    1.000000  0.375683
# 개월수*월요금       0.375683  1.000000

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".1f", cmap='coolwarm', square=True, vmin=-1, vmax=1)
plt.tight_layout()
plt.show()

# %%
numeric_df.columns
# Out:
# Index(['성별', '고령자여부', '배우자여부', '부양가족여부', '가입개월수', '전화서비스가입여부', '복수회선여부',
#        '온라인보안서비스여부', '온라인백업서비스여부', '기기보호서비스여부', '기술지원서비스여부', 'TV스트리밍이용여부',
#        '영화스트리밍이용여부', '전자청구서이용여부', '월요금', '총요금', '이탈여부', '인터넷서비스가입여부',
#        '개월수*월요금'],
#       dtype='object')

# %%
tel.columns
# Out:
# Index(['고객ID', '성별', '고령자여부', '배우자여부', '부양가족여부', '가입개월수', '전화서비스가입여부',
#        '복수회선여부', '인터넷서비스유형', '온라인보안서비스여부', '온라인백업서비스여부', '기기보호서비스여부',
#        '기술지원서비스여부', 'TV스트리밍이용여부', '영화스트리밍이용여부', '계약기간유형', '전자청구서이용여부', '결제방법',
#        '월요금', '총요금', '이탈여부', '인터넷서비스가입여부', '개월수*월요금'],
#       dtype='object')

# %%
# 가입개월수에 따른 이탈률 (0 ~ 72개월)
# 평균
churn_by_tenure = tel.groupby('가입개월수')['이탈여부'].mean()

# 선 그래프
plt.figure(figsize=(10,6), facecolor='#cbf3f0')
churn_by_tenure.plot(kind='line',
                     color='#2ec4b6',
                     marker='o',
                     markerfacecolor='#2ec4b6',
                     markeredgewidth=0
                    )
plt.title('[가입개월수에 따른 이탈률]', fontsize=15, fontweight='bold')
plt.xlabel('가입개월수', fontsize=11)
plt.ylabel('이탈률', fontsize=11)

plt.grid(True, linestyle='--')
plt.show()

# 이탈한 고객 수 / 가입개월수 별 전체 고객수 => 이탈률

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=tel, x='가입개월수', hue='이탈여부',bins=24, color='pastel', multiple='stack')

plt.title('가입개월수 분포', fontsize=15, fontweight='bold')
plt.xlabel('가입개월수', fontsize=12)
plt.ylabel('고객 수', fontsize=12)
plt.grid(True, linestyle='--')
plt.legend(title='이탈 여부', labels=['잔류','이탈'])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=tel, x='총요금', hue='이탈여부', bins=40, kde=True, palette='Set2', alpha=0.5)
plt.title('총요금에 따른 이탈 여부 분포', fontsize=14)
plt.xlabel('총요금')
plt.ylabel('고객 수')
plt.grid(True)
plt.legend(title='이탈 여부', labels=['잔류','이탈'])
plt.show()

# %%
plt.figure(figsize=(10, 6))

# 이탈 고객 (1)
sns.kdeplot(
    data=tel[tel['이탈여부'] == 1],
    x='총요금',
    label='이탈',
    color='#ff6b6b',
    fill=True,
    alpha=0.4
)

# 잔류 고객 (0)
sns.kdeplot(
    data=tel[tel['이탈여부'] == 0],
    x='총요금',
    label='잔류',
    color='#4dabf7',
    fill=True,
    alpha=0.4
)

plt.title('총요금에 따른 이탈 여부 분포 (KDE)', fontsize=14, fontweight='bold')
plt.xlabel('총요금')
plt.ylabel('밀도')
plt.legend(title='이탈 여부')
plt.grid(True, linestyle='--', alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=tel, x='이탈여부', y='월요금',palette='Set2')
plt.title('이탈 여부에 따른 월요금 분포', fontsize=14, fontweight='bold')
plt.xlabel('이탈 여부')
plt.ylabel('월요금')
plt.grid(True, linestyle='--')
plt.show()
# Out:
# C:\Users\win11\AppData\Local\Temp\ipykernel_19164\776508849.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=tel, x='이탈여부', y='월요금',palette='Set2')

# %%
tel['총요금'].max()
# Out:
# 8684.8

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=tel, x='월요금', hue='이탈여부',bins=15, color='pastel', multiple='stack')

plt.title('월요금 분포', fontsize=15, fontweight='bold')
plt.xlabel('월요금', fontsize=12)
plt.ylabel('고객 수', fontsize=12)
plt.grid(True, linestyle='--')
plt.show()
